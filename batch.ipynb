# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Sanskruti\Desktop\deep learning 100 days\concertriccir2.csv')
# Out:
#   Cell In[2], line 1
#     df=pd.read_csv('C:\Users\Sanskruti\Desktop\deep learning 100 days\concertriccir2.csv')
#                                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
